# %% [markdown]
# # Sorting & Ranking

# %% [markdown]
# #df.sort_values

# %%
import pandas as pd

# %%
data=pd.read_excel("100-sales-records.xlsx")
data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
print (data.sort_index(ascending=False))
# Out:
#                                Region                Country        Item_Type  \
# 99                 Sub_Saharan Africa             Mozambique        Household
# 98                      North America                 Mexico    Personal Care
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 96                               Asia               Malaysia           Fruits
# 95                 Sub_Saharan Africa                   Mali          Clothes
# ..                                ...                    ...              ...
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 2                              Europe                 Russia  Office Supplies
# 1   Central America and the Caribbean                Grenada           Cereal
# 0               Australia and Oceania                 Tuvalu        Baby Food
#
# ...

# %%
new_data = data.sort_values('Total_Profit', ascending=False)
new_data.head(10)
# Out:
#                                Region      Country  Item_Type Sales_Channel  \
# 74       Middle East and North Africa     Pakistan  Cosmetics       Offline
# 79              Australia and Oceania       Samoa   Cosmetics        Online
# 46                             Europe      Iceland  Cosmetics        Online
# 30                             Europe  Switzerland  Cosmetics       Offline
# 13  Central America and the Caribbean     Honduras  Household       Offline
# 93                             Europe      Romania  Cosmetics        Online
# 33                               Asia      Myanmar  Household       Offline
# 41       Middle East and North Africa   Azerbaijan  Cosmetics        Online
# 59                 Sub_Saharan Africa     Djibouti  Cosmetics       Offline
# 16                               Asia    Sri Lanka  Cosmetics       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# ...

# %%
data.sort_values('Item_Type').head(20)
# Out:
#                                Region                           Country  \
# 0               Australia and Oceania                            Tuvalu
# 21                             Europe                          Portugal
# 20                             Europe                            Norway
# 87                 Sub_Saharan Africa                        The Gambia
# 61                             Europe                        San Marino
# 78                             Europe                            Monaco
# 5               Australia and Oceania                   Solomon Islands
# 94  Central America and the Caribbean                         Nicaragua
# 76              Australia and Oceania    Federated States of Micronesia
# 91              Australia and Oceania                         Australia
# 89                             Europe                          Slovenia
# 72                 Sub_Saharan Africa  Democratic Republic of the Congo
# ...

# %%
data.sort_values('Item_Type',ascending=False).head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 77 2011-10-23      90.93      574951.92     235601.16
# 84 2012-07-04      90.93      994765.42     407630.41
# 43 2012-10-11      90.93       26344.26      10795.23
# 7  2012-07-27      90.93     1245112.92     510216.66
# 97 2016-06-29      90.93      228779.10      93748.05

# %% [markdown]
# # Sort Single Column

# %%
data.sort_values(by=['Item_Type'], ascending=False).head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 77 2011-10-23      90.93      574951.92     235601.16
# 84 2012-07-04      90.93      994765.42     407630.41
# 43 2012-10-11      90.93       26344.26      10795.23
# 7  2012-07-27      90.93     1245112.92     510216.66
# 97 2016-06-29      90.93      228779.10      93748.05

# %%
data.sort_values(by=['Item_Type'], inplace=True, ascending=False)

# %% [markdown]
# # Sort by Multiple Column

# %%
data.sort_values(by=['Item_Type','Country'])
# Out:
#                    Region          Country   Item_Type Sales_Channel  \
# 78                 Europe           Monaco   Baby Food       Offline
# 20                 Europe           Norway   Baby Food        Online
# 21                 Europe         Portugal   Baby Food        Online
# 61                 Europe       San Marino   Baby Food        Online
# 5   Australia and Oceania  Solomon Islands   Baby Food        Online
# ..                    ...              ...         ...           ...
# 84     Sub_Saharan Africa            Kenya  Vegetables        Online
# 10                   Asia       Kyrgyzstan  Vegetables        Online
# 77                   Asia             Laos  Vegetables       Offline
# 97     Sub_Saharan Africa     Sierra Leone  Vegetables       Offline
# 43                 Europe         Slovakia  Vegetables        Online
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 78              H 2012-02-06     159.42     2198981.92     825738.04
# ...

# %%
data.sort_values(by=['Item_Type','Sales_Channel'])
# Out:
#                    Region          Country   Item_Type Sales_Channel  \
# 87     Sub_Saharan Africa       The Gambia   Baby Food       Offline
# 78                 Europe           Monaco   Baby Food       Offline
# 0   Australia and Oceania           Tuvalu   Baby Food       Offline
# 5   Australia and Oceania  Solomon Islands   Baby Food        Online
# 61                 Europe       San Marino   Baby Food        Online
# ..                    ...              ...         ...           ...
# 97     Sub_Saharan Africa     Sierra Leone  Vegetables       Offline
# 84     Sub_Saharan Africa            Kenya  Vegetables        Online
# 43                 Europe         Slovakia  Vegetables        Online
# 7      Sub_Saharan Africa     Burkina Faso  Vegetables        Online
# 10                   Asia       Kyrgyzstan  Vegetables        Online
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 87              M 2014-03-20     159.42     1419101.52     532885.74
# ...

# %%
data.sort_values(by=['Item_Type','Country'], ascending=False)
# Out:
#                    Region          Country   Item_Type Sales_Channel  \
# 43                 Europe         Slovakia  Vegetables        Online
# 97     Sub_Saharan Africa     Sierra Leone  Vegetables       Offline
# 77                   Asia             Laos  Vegetables       Offline
# 10                   Asia       Kyrgyzstan  Vegetables        Online
# 84     Sub_Saharan Africa            Kenya  Vegetables        Online
# ..                    ...              ...         ...           ...
# 5   Australia and Oceania  Solomon Islands   Baby Food        Online
# 61                 Europe       San Marino   Baby Food        Online
# 21                 Europe         Portugal   Baby Food        Online
# 20                 Europe           Norway   Baby Food        Online
# 78                 Europe           Monaco   Baby Food       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 43              H 2012-10-11      90.93       26344.26      10795.23
# ...

# %%
data1 = {"StudentName": ["Reena", "Anil", "Mansi", "Jaman","Reena"],
        "Age": [24, 28, 26, 24,24],
        "Sex": ["Female", "Male", "Female", "Male","Female"]}
data1 = pd.DataFrame(data1)
print(data1)
# Out:
#   StudentName  Age     Sex
# 0       Reena   24  Female
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 3       Jaman   24    Male
# 4       Reena   24  Female

# %%
data1=data1.drop_duplicates()
print(data)
# Out:
#                    Region       Country   Item_Type Sales_Channel  \
# 77                   Asia          Laos  Vegetables       Offline
# 84     Sub_Saharan Africa         Kenya  Vegetables        Online
# 43                 Europe      Slovakia  Vegetables        Online
# 7      Sub_Saharan Africa  Burkina Faso  Vegetables        Online
# 97     Sub_Saharan Africa  Sierra Leone  Vegetables       Offline
# ..                    ...           ...         ...           ...
# 20                 Europe        Norway   Baby Food        Online
# 21                 Europe      Portugal   Baby Food        Online
# 87     Sub_Saharan Africa    The Gambia   Baby Food       Offline
# 78                 Europe        Monaco   Baby Food       Offline
# 0   Australia and Oceania        Tuvalu   Baby Food       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 77              C 2011-10-23      90.93      574951.92     235601.16
# ...

# %%
data1.sort_values(by=['Sex'],ascending=False)
# Out:
#   StudentName  Age     Sex
# 1        Anil   28    Male
# 3       Jaman   24    Male
# 0       Reena   24  Female
# 2       Mansi   26  Female

# %%
data1.sort_values(by=['Age','Sex'],ascending=False)
# Out:
#   StudentName  Age     Sex
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 3       Jaman   24    Male
# 0       Reena   24  Female

# %%
data1.sort_values(by=['Sex','Age'],ascending=False)
# Out:
#   StudentName  Age     Sex
# 1        Anil   28    Male
# 3       Jaman   24    Male
# 2       Mansi   26  Female
# 0       Reena   24  Female

# %% [markdown]
# # Ranking Rows of Pandas DataFrame

# %% [markdown]
# #The rank is returned on the basis of position after sorting

# %%
d = {
'Name':['Alisa','Bobby','Cathrine','Alisa','Bobby','Cathrine',
'Alisa','Bobby','Cathrine','Alisa','Bobby','Cathrine'],
'Subject':['Mathematics','Mathematics','Mathematics','Science','Science','Science',
'History','History','History','Economics','Economics','Economics'],
'Score':[62,47,55,74,31,77,85,63,42,62,89,85]}
df = pd.DataFrame(d)
df
# Out:
#         Name      Subject  Score
# 0      Alisa  Mathematics     62
# 1      Bobby  Mathematics     47
# 2   Cathrine  Mathematics     55
# 3      Alisa      Science     74
# 4      Bobby      Science     31
# 5   Cathrine      Science     77
# 6      Alisa      History     85
# 7      Bobby      History     63
# 8   Cathrine      History     42
# 9      Alisa    Economics     62
# 10     Bobby    Economics     89
# 11  Cathrine    Economics     85

# %%
# Ranking of score ascending order
 
df['score_ranked']=df['Score'].rank(ascending=1)
df
# Out:
#         Name      Subject  Score  score_ranked
# 0      Alisa  Mathematics     62           5.5
# 1      Bobby  Mathematics     47           3.0
# 2   Cathrine  Mathematics     55           4.0
# 3      Alisa      Science     74           8.0
# 4      Bobby      Science     31           1.0
# 5   Cathrine      Science     77           9.0
# 6      Alisa      History     85          10.5
# 7      Bobby      History     63           7.0
# 8   Cathrine      History     42           2.0
# 9      Alisa    Economics     62           5.5
# 10     Bobby    Economics     89          12.0
# 11  Cathrine    Economics     85          10.5

# %%
# Ranking of score descending order
df['score_ranked']=df['Score'].rank(ascending=0)
df
# Out:
#         Name      Subject  Score  score_ranked
# 0      Alisa  Mathematics     62           7.5
# 1      Bobby  Mathematics     47          10.0
# 2   Cathrine  Mathematics     55           9.0
# 3      Alisa      Science     74           5.0
# 4      Bobby      Science     31          12.0
# 5   Cathrine      Science     77           4.0
# 6      Alisa      History     85           2.5
# 7      Bobby      History     63           6.0
# 8   Cathrine      History     42          11.0
# 9      Alisa    Economics     62           7.5
# 10     Bobby    Economics     89           1.0
# 11  Cathrine    Economics     85           2.5

# %% [markdown]
# # rank the dataframe in descending order of score and if found two scores are same then assign the minimum rank to both the score as shown below

# %%
# in this example score 62 is found twice and is ranked by minimum value of 7

# %%
# Ranking of score in descending order by minimum value
df['score_ranked']=df['Score'].rank(ascending=0,method='min')
df
# Out:
#         Name      Subject  Score  score_ranked
# 0      Alisa  Mathematics     62           7.0
# 1      Bobby  Mathematics     47          10.0
# 2   Cathrine  Mathematics     55           9.0
# 3      Alisa      Science     74           5.0
# 4      Bobby      Science     31          12.0
# 5   Cathrine      Science     77           4.0
# 6      Alisa      History     85           2.0
# 7      Bobby      History     63           6.0
# 8   Cathrine      History     42          11.0
# 9      Alisa    Economics     62           7.0
# 10     Bobby    Economics     89           1.0
# 11  Cathrine    Economics     85           2.0

# %%
df['rank_score_subject'] = df.groupby('Subject')['Score'].rank(method='first')
df
# Out:
#         Name      Subject  Score  score_ranked  rank_score_subject
# 0      Alisa  Mathematics     62           7.0                 3.0
# 1      Bobby  Mathematics     47          10.0                 1.0
# 2   Cathrine  Mathematics     55           9.0                 2.0
# 3      Alisa      Science     74           5.0                 2.0
# 4      Bobby      Science     31          12.0                 1.0
# 5   Cathrine      Science     77           4.0                 3.0
# 6      Alisa      History     85           2.0                 3.0
# 7      Bobby      History     63           6.0                 2.0
# 8   Cathrine      History     42          11.0                 1.0
# 9      Alisa    Economics     62           7.0                 1.0
# 10     Bobby    Economics     89           1.0                 3.0
# 11  Cathrine    Economics     85           2.0                 2.0

# %%
df
# Out:
#         Name      Subject  Score  score_ranked  rank_score_subject
# 0      Alisa  Mathematics     62           7.0                 3.0
# 1      Bobby  Mathematics     47          10.0                 1.0
# 2   Cathrine  Mathematics     55           9.0                 2.0
# 3      Alisa      Science     74           5.0                 2.0
# 4      Bobby      Science     31          12.0                 1.0
# 5   Cathrine      Science     77           4.0                 3.0
# 6      Alisa      History     85           2.0                 3.0
# 7      Bobby      History     63           6.0                 2.0
# 8   Cathrine      History     42          11.0                 1.0
# 9      Alisa    Economics     62           7.0                 1.0
# 10     Bobby    Economics     89           1.0                 3.0
# 11  Cathrine    Economics     85           2.0                 2.0

# %% [markdown]
# # Rank the dataframe in python pandas by maximum value of the rank

# %%
# rank the dataframe in descending order of score and if found two scores are same then 
# assign the maximum rank to both the score as shown below

# %%
# In this example score 62 is found twice and is ranked by maximum value of 8

# %%
# Ranking of score in descending order by maximum value
 
df['score_ranked']=df['Score'].rank(ascending=0,method='max')
df
# Out:
#         Name      Subject  Score  score_ranked  rank_score_subject
# 0      Alisa  Mathematics     62           8.0                 3.0
# 1      Bobby  Mathematics     47          10.0                 1.0
# 2   Cathrine  Mathematics     55           9.0                 2.0
# 3      Alisa      Science     74           5.0                 2.0
# 4      Bobby      Science     31          12.0                 1.0
# 5   Cathrine      Science     77           4.0                 3.0
# 6      Alisa      History     85           3.0                 3.0
# 7      Bobby      History     63           6.0                 2.0
# 8   Cathrine      History     42          11.0                 1.0
# 9      Alisa    Economics     62           8.0                 1.0
# 10     Bobby    Economics     89           1.0                 3.0
# 11  Cathrine    Economics     85           3.0                 2.0

# %% [markdown]
# # Rank the dataframe in python pandas by dense rank

# %%
# rank the dataframe in descending order of score and if found two scores are same then assign the same rank . 
# Dense rank does not skip any rank (in min and max ranks are skipped)

# %% [markdown]
# # Ranking of score in descending order by dense
#
# df['score_ranked']=df['Score'].rank(ascending=0,method='average')
# df

# %% [markdown]
# # Rank the dataframe in python pandas by Group

# %%
# rank the dataframe in descending order of score by subject . 
# so ranking is done by subject wise

# %%
# Rank by Group
 
df["group_rank"] = df.groupby("Subject")["Score"].rank(ascending=0,method='average')
df
# Out:
#         Name      Subject  Score  score_ranked  rank_score_subject  group_rank
# 0      Alisa  Mathematics     62           8.0                 3.0         1.0
# 1      Bobby  Mathematics     47          10.0                 1.0         3.0
# 2   Cathrine  Mathematics     55           9.0                 2.0         2.0
# 3      Alisa      Science     74           5.0                 2.0         2.0
# 4      Bobby      Science     31          12.0                 1.0         3.0
# 5   Cathrine      Science     77           4.0                 3.0         1.0
# 6      Alisa      History     85           3.0                 3.0         1.0
# 7      Bobby      History     63           6.0                 2.0         2.0
# 8   Cathrine      History     42          11.0                 1.0         3.0
# 9      Alisa    Economics     62           8.0                 1.0         3.0
# 10     Bobby    Economics     89           1.0                 3.0         1.0
# ...

# %%
df["group_ranking"] = df.groupby("Subject")["Score"].rank(ascending=0,method='dense')
df
# Out:
#         Name      Subject  Score  score_ranked  rank_score_subject  \
# 0      Alisa  Mathematics     62           8.0                 3.0
# 1      Bobby  Mathematics     47          10.0                 1.0
# 2   Cathrine  Mathematics     55           9.0                 2.0
# 3      Alisa      Science     74           5.0                 2.0
# 4      Bobby      Science     31          12.0                 1.0
# 5   Cathrine      Science     77           4.0                 3.0
# 6      Alisa      History     85           3.0                 3.0
# 7      Bobby      History     63           6.0                 2.0
# 8   Cathrine      History     42          11.0                 1.0
# 9      Alisa    Economics     62           8.0                 1.0
# 10     Bobby    Economics     89           1.0                 3.0
# 11  Cathrine    Economics     85           3.0                 2.0
#
#     group_rank  group_ranking
# 0          1.0            1.0
# 1          3.0            3.0
# ...

# %%
data["Rank_Profit"]=data.groupby("Item_Type")["Total_Revenue"].rank(ascending=0,method='dense')

# %%
data["Rank_Profit"]
# Out:
# 77    3.0
# 84    2.0
# 43    5.0
# 7     1.0
# 97    4.0
#      ...
# 20    3.0
# 21    7.0
# 87    4.0
# 78    2.0
# 0     1.0
# Name: Rank_Profit, Length: 100, dtype: float64

# %%
# Create a new column that is the rank of the value of Total_Profit in ascending order
#Ascending =True means 1=Lowest
data['Profit_Ranked'] = data['Total_Profit'].rank(ascending=True)
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked
# 77           45.0
# 84           60.0
# 43            7.0
# ...

# %%
# Create a new column that is the rank of the value of Total_Profit in descending order
#Ascending =False means 1=Highest
data['Profit_Ranked'] = data['Total_Profit'].rank(ascending=False)
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked
# 77           56.0
# 84           41.0
# 43           94.0
# ...

# %%
data['rank_Profit_by_Item_Type'] = data.groupby('Item_Type')['Total_Profit'].rank(method='first')
data
# Out:
#                    Region       Country   Item_Type Sales_Channel  \
# 77                   Asia          Laos  Vegetables       Offline
# 84     Sub_Saharan Africa         Kenya  Vegetables        Online
# 43                 Europe      Slovakia  Vegetables        Online
# 7      Sub_Saharan Africa  Burkina Faso  Vegetables        Online
# 97     Sub_Saharan Africa  Sierra Leone  Vegetables       Offline
# ..                    ...           ...         ...           ...
# 20                 Europe        Norway   Baby Food        Online
# 21                 Europe      Portugal   Baby Food        Online
# 87     Sub_Saharan Africa    The Gambia   Baby Food       Offline
# 78                 Europe        Monaco   Baby Food       Offline
# 0   Australia and Oceania        Tuvalu   Baby Food       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 77              C 2011-10-23      90.93      574951.92     235601.16
# ...

# %% [markdown]
# # Rank in ascending order

# %%
data['Rank']=data['Total_Revenue'].rank(ascending=0)
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked  rank_Profit_by_Item_Type  Rank
# ...

# %%
data['Rank']=data['Total_Revenue'].rank(ascending=1)
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked  rank_Profit_by_Item_Type  Rank
# ...

# %%
data['Rank']=data['Total_Revenue'].rank(method='max')
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked  rank_Profit_by_Item_Type  Rank
# ...

# %%
data['Rank']=data['Total_Revenue'].rank(method='min')
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked  rank_Profit_by_Item_Type  Rank
# ...

# %%
data['Rank']=data['Total_Revenue'].rank(method='average')
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked  rank_Profit_by_Item_Type  Rank
# ...

# %%
data['Rank']=data['Total_Revenue'].rank(method='dense')
data.head()
# Out:
#                 Region       Country   Item_Type Sales_Channel Order_Priority  \
# 77                Asia          Laos  Vegetables       Offline              C
# 84  Sub_Saharan Africa         Kenya  Vegetables        Online              L
# 43              Europe      Slovakia  Vegetables        Online              H
# 7   Sub_Saharan Africa  Burkina Faso  Vegetables        Online              H
# 97  Sub_Saharan Africa  Sierra Leone  Vegetables       Offline              C
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  Rank_Profit  \
# 77 2011-10-23      90.93      574951.92     235601.16          3.0
# 84 2012-07-04      90.93      994765.42     407630.41          2.0
# 43 2012-10-11      90.93       26344.26      10795.23          5.0
# 7  2012-07-27      90.93     1245112.92     510216.66          1.0
# 97 2016-06-29      90.93      228779.10      93748.05          4.0
#
#     Profit_Ranked  rank_Profit_by_Item_Type  Rank
# ...
