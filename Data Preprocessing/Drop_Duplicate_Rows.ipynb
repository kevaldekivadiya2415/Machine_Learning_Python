# %%
import pandas as pd

# %%
import pandas as pd

# %%
data=pd.read_excel("100-sales-records.xlsx")

# %%
data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
data = {"StudentName": ["Reena", "Anil", "Mansi", "Jaman","Reena"],
        "Age": [24, 28, 26, 24,24],
        "Sex": ["Female", "Male", "Female", "Male","Female"]}
df = pd.DataFrame(data)
print(df)
# Out:
#   StudentName  Age     Sex
# 0       Reena   24  Female
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 3       Jaman   24    Male
# 4       Reena   24  Female

# %% [markdown]
# # Drop Duplicate Rows
# #drop_duplicates returns only the dataframe’s unique values. Removing duplicate records is sample.

# %%
df = df.drop_duplicates()
print(df)
# Out:
#   StudentName  Age     Sex
# 0       Reena   24  Female
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 3       Jaman   24    Male

# %% [markdown]
# #To remove duplicates of only one or a subset of columns, specify subset as the individual column or list of columns that should be unique.
# To do this conditional on a different column’s value,
# you can sort_values(colname) and specify keep equals either first or last.

# %%
df = df.sort_values('Age', ascending=False)
df
# Out:
#   StudentName  Age     Sex
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 0       Reena   24  Female
# 3       Jaman   24    Male

# %%
df = df.sort_values('Age', ascending=False)
df

df = df.drop_duplicates(subset='Age', keep='first')
df
# Out:
#   StudentName  Age     Sex
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 0       Reena   24  Female

# %%
# Remove duplicates of only one or a subset of columns-

# %%
df = df.drop_duplicates(subset='StudentName', keep='first')
df
# Out:
#   StudentName  Age     Sex
# 1        Anil   28    Male
# 2       Mansi   26  Female
# 0       Reena   24  Female

# %%
data=pd.read_excel("100-sales-records.xlsx")
data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
new_data = data.drop_duplicates()
new_data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
new_data = data.sort_values('Total_Profit', ascending=False)
new_data
# Out:
#                                Region      Country      Item_Type  \
# 74       Middle East and North Africa     Pakistan      Cosmetics
# 79              Australia and Oceania       Samoa       Cosmetics
# 46                             Europe      Iceland      Cosmetics
# 30                             Europe  Switzerland      Cosmetics
# 13  Central America and the Caribbean     Honduras      Household
# ..                                ...          ...            ...
# 10                               Asia   Kyrgyzstan     Vegetables
# 47                             Europe  Switzerland  Personal Care
# 23              Australia and Oceania  New Zealand         Fruits
# 71       Middle East and North Africa        Libya         Fruits
# 88       Middle East and North Africa       Kuwait         Fruits
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 74       Offline              L 2013-08-16     263.33     4324782.40
# ...

# %%
new_data = data.sort_values('Total_Profit', ascending=False)
new_data
# Out:
#                                Region      Country      Item_Type  \
# 74       Middle East and North Africa     Pakistan      Cosmetics
# 79              Australia and Oceania       Samoa       Cosmetics
# 46                             Europe      Iceland      Cosmetics
# 30                             Europe  Switzerland      Cosmetics
# 13  Central America and the Caribbean     Honduras      Household
# ..                                ...          ...            ...
# 10                               Asia   Kyrgyzstan     Vegetables
# 47                             Europe  Switzerland  Personal Care
# 23              Australia and Oceania  New Zealand         Fruits
# 71       Middle East and North Africa        Libya         Fruits
# 88       Middle East and North Africa       Kuwait         Fruits
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 74       Offline              L 2013-08-16     263.33     4324782.40
# ...

# %%
new_data = data.sort_values('Region', ascending=False)
new_data
# Out:
#                 Region     Country        Item_Type Sales_Channel  \
# 99  Sub_Saharan Africa  Mozambique        Household       Offline
# 37  Sub_Saharan Africa  The Gambia             Meat        Online
# 49  Sub_Saharan Africa  Mauritania  Office Supplies       Offline
# 84  Sub_Saharan Africa       Kenya       Vegetables        Online
# 83  Sub_Saharan Africa      Zambia           Snacks        Online
# ..                 ...         ...              ...           ...
# 10                Asia  Kyrgyzstan       Vegetables        Online
# 96                Asia    Malaysia           Fruits       Offline
# 44                Asia     Myanmar          Clothes        Online
# 77                Asia        Laos       Vegetables       Offline
# 33                Asia     Myanmar        Household       Offline
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 99              L 2012-02-15     502.54     3586605.09     889472.91
# ...

# %%
new_data = data.drop_duplicates(subset='Region',keep='first')
new_data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 10                               Asia             Kyrgyzstan       Vegetables
# 36       Middle East and North Africa                  Syria           Fruits
# 75                      North America                 Mexico        Household
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0        Offline              H 2010-06-27     159.42     2533654.00
# 1         Online              C 2012-09-15     117.11      576782.80
# 2        Offline              L 2014-08-05     524.96     1158502.59
# ...

# %%
new_data = data.drop_duplicates(subset='Region',keep='first')
new_data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 10                               Asia             Kyrgyzstan       Vegetables
# 36       Middle East and North Africa                  Syria           Fruits
# 75                      North America                 Mexico        Household
#
#    Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0        Offline              H 2010-06-27     159.42     2533654.00
# 1         Online              C 2012-09-15     117.11      576782.80
# 2        Offline              L 2014-08-05     524.96     1158502.59
# ...

# %% [markdown]
# # Identify Duplicate Rows based on Specific Columns

# %%
new_data = data.drop_duplicates(subset=['Item_Type','Sales_Channel'],keep='first')
new_data.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 5              Australia and Oceania        Solomon Islands        Baby Food
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 5        Online              C 2015-02-21     159.42      759202.72
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %%
new_data = data.drop_duplicates(subset=['Item_Type','Sales_Channel'],keep='last')
new_data
# Out:
#                                Region                         Country  \
# 37                 Sub_Saharan Africa                      The Gambia
# 47                             Europe                     Switzerland
# 58                             Europe                  United Kingdom
# 60              Australia and Oceania                       Australia
# 61                             Europe                      San Marino
# 69                 Sub_Saharan Africa                      Madagascar
# 73                 Sub_Saharan Africa                        Djibouti
# 74       Middle East and North Africa                        Pakistan
# 76              Australia and Oceania  Federated States of Micronesia
# 83                 Sub_Saharan Africa                          Zambia
# 84                 Sub_Saharan Africa                           Kenya
# 87                 Sub_Saharan Africa                      The Gambia
# ...

# %%
new_data = data.drop_duplicates(subset=['Region','Item_Type','Sales_Channel'],keep='first')
new_data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 91              Australia and Oceania              Australia        Beverages
# 92       Middle East and North Africa             Azerbaijan  Office Supplies
# 94  Central America and the Caribbean              Nicaragua        Beverages
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
#
# ...
